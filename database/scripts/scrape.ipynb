# %%
# %pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', 'GOOGL']
portfolio_df = pd.concat([yf.download(ticker, group_by='Ticker', period='2y', interval='1d').assign(ticker=ticker) for ticker in tickers], ignore_index=False)
portfolio_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-08-01  161.009995  163.589996  160.889999  161.509995  159.703140
# 2022-08-02  160.100006  162.410004  159.630005  160.009995  158.219910
# 2022-08-03  160.839996  166.589996  160.750000  166.130005  164.271500
# 2022-08-04  166.009995  167.190002  164.429993  165.809998  163.955063
# 2022-08-05  163.210007  165.850006  163.000000  165.350006  163.727341
# ...                ...         ...         ...         ...         ...
# 2024-07-24  173.600006  176.190002  171.820007  172.630005  172.630005
# 2024-07-25  172.520004  173.419998  167.190002  167.279999  167.279999
# 2024-07-26  167.149994  168.089996  164.059998  167.000000  167.000000
# ...

# %%
import os
cwd = os.getcwd()
path = cwd + "/data_snapshot.csv"
portfolio_df.to_csv(path)
